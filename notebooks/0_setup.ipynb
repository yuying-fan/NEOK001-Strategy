# %% [markdown]
# # Set up environment for the project

# %%
#create env
conda create -n neok001 python=3.11 -y

#activate
conda activate neok001

#install packages
pip install pandas numpy matplotlib seaborn requests jupyter ipykernel nbformat openpyxl

#In case can't find as kernel in VSCode, register:
##python -m ipykernel install --user --name neok001 --display-name "neok001"

# %%
# after setting up your env
conda env export > environment.yml
