# %% [markdown]
# # US-focused ADC Patent Landscape
# Using the `US-enforced-patents.jsonl` to examine US-enforced patents, their composition and filing patterns

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 100) # Set max column width to 100 characters for better readability

df = pd.read_json("../../data/raw/US-enforced-patents.jsonl", lines=True)

print(len(df))
print(df.columns)
df.head()
# Out:
# 2331
# Index(['lens_id', 'jurisdiction', 'doc_number', 'kind', 'date_published',
#        'doc_key', 'docdb_id', 'lang', 'biblio', 'families', 'sequence_listing',
#        'legal_status', 'abstract', 'claims', 'description',
#        'publication_type'],
#       dtype='str')
#                lens_id jurisdiction   doc_number kind date_published  \
# 0  001-164-692-658-169           US      9107960   B2     2015-08-18
# 1  039-300-232-515-637           US      9334318   B1     2016-05-10
# 2  094-825-731-979-424           US     12318455   B2     2025-06-03
# 3  165-451-121-516-190           US  20160129013   A1     2016-05-12
# 4  064-424-066-709-583           US     11944689   B2     2024-04-02
#
#                       doc_key   docdb_id lang  \
# 0      US_9107960_B2_20150818  443471947   en
# 1      US_9334318_B1_20160510  452042120   en
# 2     US_12318455_B2_20250603  631938788   en
# 3  US_20160129013_A1_20160512  452234872   en
# 4     US_11944689_B2_20240402  609044858   en
# ...

# %%
df["claims"].apply(type).value_counts()
#output shows 9 are float, so NaN
# Out:
# claims
# <class 'list'>     2322
# <class 'float'>       9
# Name: count, dtype: int64

# %%
#Looking at claims value for first row
df["claims"].iloc[0]
# Out:
# [{'claims': [{'claim_text': ['1. A method to produce a compound, CL2A-SN-38, of the structure,',
#      'comprising performing a reaction scheme as shown:',
#      'further comprising reacting SN-38 with tert-butyldimethylsilsl chloride (TBDMS-Cl) to produce 10-O-TBDMS-SN-38 (intermediate 4), wherein the reaction is carried out in dichloromethane solvent.']},
#    {'claim_text': ['2. The method of claim 1 , further comprising reacting 10-O-TBDMS-SN-38 (intermediate 4) with triphosgene and DMAP to make 10-O-TBDMS-SN-38-20-O-chloroformate (reactive intermediate 5), wherein the reaction is performed by adding triphosgene to a dichloromethane reaction mixture that contains intermediate 4, and the triphosgene is added in portions, to reduce exothermic reaction during large scale manufacture and maintain high reaction yield.']},
#    {'claim_text': ['3. The method of claim 1 , further comprising precipitating Lys(MMT)-PABOH (intermediate 2) with heptane.']},
# ...

# %%
#Though it's US jurisdiction, for sanity, just double checking that language is english for all
langs = df["claims"].apply(
    lambda x: x[0].get("lang") if isinstance(x, list) and len(x) > 0 else None
)
langs.value_counts(dropna=False)
# Out:
# claims
# en     2322
# NaN       9
# Name: count, dtype: int64

# %%
# So the Claim column is a list but contains one dictionary, with keys of claims and language. 
# In that claims key, the value is another list of claim dictionaries where each has the key of claim_text and the value is the text
# This column is nested and odd looking.

# I'm just gonna extract ALL claim text into a per row, so flatten it:
def extract_all_claim_text(claim_obj):
    if not isinstance(claim_obj, list) or len(claim_obj) == 0: 
        return "" #For the 9 rows that don't have a list in their claims column (are float, NaN), just return an empty string
    
    claim_block = claim_obj[0]  # Take that first dictionary in [{ "claims": [...], "lang": "en" }]
    
    if "claims" not in claim_block: #just in case, confirm claims key exists
        return ""
    
    full_text = [] #initiate list
    
    for claim in claim_block["claims"]: #inside the list in the dictionary, [{[ ]}]
        text_parts = claim.get("claim_text", []) #grab the value of claim_text key. Return [] if key doesn't exist
        if isinstance(text_parts, list): #if text_parts we grabbed is a list (should be), then
            full_text.append(" ".join(text_parts)) #glue all items in list into one string, with space in between
    
    return " ".join(full_text) #combine all claims text

# %%
df["claims_text"] = df["claims"].apply(extract_all_claim_text)

# %%
df["claims_text"].iloc[0]
# Out:
# "1. A method to produce a compound, CL2A-SN-38, of the structure, comprising performing a reaction scheme as shown: further comprising reacting SN-38 with tert-butyldimethylsilsl chloride (TBDMS-Cl) to produce 10-O-TBDMS-SN-38 (intermediate 4), wherein the reaction is carried out in dichloromethane solvent. 2. The method of claim 1 , further comprising reacting 10-O-TBDMS-SN-38 (intermediate 4) with triphosgene and DMAP to make 10-O-TBDMS-SN-38-20-O-chloroformate (reactive intermediate 5), wherein the reaction is performed by adding triphosgene to a dichloromethane reaction mixture that contains intermediate 4, and the triphosgene is added in portions, to reduce exothermic reaction during large scale manufacture and maintain high reaction yield. 3. The method of claim 1 , further comprising precipitating Lys(MMT)-PABOH (intermediate 2) with heptane. 4. The method of claim 3 , further comprising assaying residual diethylamine in the precipitated intermediate 2 and purifying the precip
# ...

# %%
(df["claims_text"] == "").sum()
#So all 2322 rows were flattened, and original 9 NaN rows are empty
# Out:
# np.int64(9)

# %%
#Just checking how much text these claims text will contain
df["claims_text"].str.len().describe()
# Out:
# count      2331.000000
# mean       9635.889318
# std       11887.840847
# min           0.000000
# 25%        3614.500000
# 50%        5964.000000
# 75%       11138.000000
# max      178120.000000
# Name: claims_text, dtype: float64

# %%
#As this is going to be inputted into the model via OpenAI's API, need to ensure not too large
df["claims_text"].str.len().sum()
# Out:
# np.int64(22461258)

# %%
empty_claims = df[df["claims_text"] == ""] #grab those 9 empty claim rows

# %%
empty_claims[["lens_id", "kind", "legal_status"]]
# Out:
#                   lens_id kind  \
# 417   032-240-698-890-336   A1
# 431   053-807-865-739-075   A1
# 798   029-853-159-129-12X   A1
# 1042  022-873-617-525-132   A1
# 1212  058-165-013-366-539   A1
# 1421  184-270-747-563-446   B2
# 1718  196-857-624-941-935   A1
# 2197  013-287-333-155-311   A1
# 2327  098-651-403-196-496   A1
#
#                                                                                              legal_status
# 417   {'calculation_log': ['Application Filing Date: 2021-02-19', 'Earliest Filing Date: 2021-02-19 pr...
# 431   {'calculation_log': ['Application Filing Date: 2022-08-18', 'Earliest Filing Date: 2021-02-18 pr...
# 798   {'calculation_log': ['Application Filing Date: 2021-01-15', 'Earliest Filing Date: 2021-01-15 pr...
# 1042  {'granted': True, 'grant_date': '2015-05-12', 'anticipated_term_date': '2033-04-27', 'calculatio...
# 1212  {'calculation_log': ['Application Filing Date: 2021-01-29', 'Earliest Filing Date: 2021-01-29 pr...
# ...

# %% [markdown]
# These are patents, so claims should not be empty
# - Looking in The Lens, claims information is "currently unavailable" for these 9 patents
# - So will manually fill in (since it is just 9) using Google Patents

# %%
#For easier searching, will grab the title
row = empty_claims.iloc[0]
row["biblio"]
# Out:
# {'publication_reference': {'jurisdiction': 'US',
#   'doc_number': '20230075822',
#   'kind': 'A1',
#   'date': '2023-03-09'},
#  'application_reference': {'jurisdiction': 'US',
#   'doc_number': '202117904677',
#   'kind': 'A',
#   'date': '2021-02-19'},
#  'application_number': '17/904,677',
#  'priority_claims': {'claims': [{'jurisdiction': 'US',
#     'doc_number': '202117904677',
#     'kind': 'A',
#     'date': '2021-02-19',
#     'sequence': 1},
#    {'jurisdiction': 'US',
#     'doc_number': '202062979327',
#     'kind': 'P',
#     'date': '2020-02-20',
#     'sequence': 2},
#    {'jurisdiction': 'CA',
#     'doc_number': '2021050183',
#     'kind': 'W',
#     'date': '2021-02-19',
#     'sequence': 3}],
#   'earliest_claim': {'date': '2020-02-20'}},
#  'invention_title': [{'text': 'USE OF CASTALAGIN OR ANALOGS THEREOF FOR ANTI-CANCER EFFICACY AND TO INCREASE THE RESPONSE TO IMMUNE CHECKPOINT INHIBITORS',
#    'lang': 'en'}],
#  'parties': {'applicants': [{'residence': 'CA',
# ...

# %%
#So title is in invention_title

#Grab the title using it:
empty_titles = empty_claims.apply(
    lambda row: row["biblio"].get("invention_title", [{}])[0].get("text")
    if isinstance(row["biblio"], dict)
    else None,
    axis=1
)

# %%
#To search on google patents, also easier to get document number and not lens-id
def get_pub_number(biblio):
    if not isinstance(biblio, dict):
        return None
    
    pub = biblio.get("publication_reference", {})
    
    jurisdiction = pub.get("jurisdiction")
    doc_number = pub.get("doc_number")
    kind = pub.get("kind")
    
    if jurisdiction and doc_number and kind:
        return f"{jurisdiction}{doc_number}{kind}"

    return None


empty_pub_numbers = empty_claims["biblio"].apply(get_pub_number)

pd.set_option("display.max_colwidth", None) #resest with pd.reset_option("display.max_colwidth")

pd.DataFrame({
    "lens_id": empty_claims["lens_id"],
    "publication_number": empty_pub_numbers,
    "title": empty_titles
})
# Out:
#                   lens_id publication_number  \
# 417   032-240-698-890-336    US20230075822A1
# 431   053-807-865-739-075    US20230073248A1
# 798   029-853-159-129-12X    US20230075925A1
# 1042  022-873-617-525-132    US20120190622A1
# 1212  058-165-013-366-539    US20230075779A1
# 1421  184-270-747-563-446       US12503518B2
# 1718  196-857-624-941-935    US20230074657A1
# 2197  013-287-333-155-311    US20230076371A1
# 2327  098-651-403-196-496    US20230074385A1
#
#                                                                                                                            title
# 417   USE OF CASTALAGIN OR ANALOGS THEREOF FOR ANTI-CANCER EFFICACY AND TO INCREASE THE RESPONSE TO IMMUNE CHECKPOINT INHIBITORS
# 431                                         COMPOSITIONS AND METHODS FOR INDUCING IMMUNE TOLERANCE IN TRANSPLANTATION RECIPIENTS
# 798                       NON-PERIPHERAL QUATERNARY AMMONIUM-MODIFIED ZINC PHTHALOCYANINE AND PREPARATION METHOD AND USE THEREOF
# ...

# %% [markdown]
# So I searched the publication_number on Google Patents, cross checked with title
# - Then copy over their claims to the variables below

# %%
claim_text_032_240_698_890_336 = "1. A method for treating a subject suffering from a cancer resistant to immunotherapy comprising administering to the subject a therapeutically effective amount of castalagin or an analog thereof. 2. The method of claim 1, wherein the immunotherapy comprises immune checkpoint inhibitor therapy. 3. The method of claim 2, wherein the immune checkpoint inhibitor is a Programmed cell death-1 (PD-1) inhibitor, a cytotoxic T-lymphocyte-associated antigen 4 (CTLA-4) inhibitor, or a Programmed death-ligand 1 (PD-L1) inhibitor. 4. (canceled) 5. The method of claim 3 [[or 4]], wherein the immune checkpoint inhibitor is an anti-PD-1 blocking antibody. 6. The method of claim 1, wherein the castalagin. 7. (canceled) 8. The method of claim 1, wherein the method comprises administering a pharmaceutical composition comprising castalagin. 9. The method of claim 1, wherein the castalagin or analog thereof is formulated for delivery of the castalagin or analog thereof into the intestines. 10. (canceled) 11. The method of claim 1, wherein the cancer is lung cancer or breast cancer. 12. The method of claim 11, wherein the lung cancer is non-small cell lung cancer (NSCLC), and wherein the breast cancer is triple-negative breast cancer (TNBC). 13. (canceled) 14. The method of claim 1, further comprising administering an effective amount of the immune checkpoint inhibitor to the subject. 15. A method for enhancing the anti-tumor immune response in a subject suffering from cancer, the method comprising administering to the subject a therapeutically effective amount of castalagin or an analog thereof. 16. The method of claim 15, wherein the anti-tumor immune response is the anti-tumor T-cell response. 17. The method of claim 15, wherein the method further comprising administering a therapeutically effective amount of an immune checkpoint inhibitor to the subject. 18. The method of claim 17, wherein the immune checkpoint inhibitor is a Programmed cell death-1 (PD-1) inhibitor, a cytotoxic T-lymphocyte-associated antigen 4 (CTLA-4) inhibitor, or a Programmed death-ligand 1 (PD-L1) inhibitor. 19. (canceled) 20. The method of claim 18, wherein the immune checkpoint inhibitor is an anti-PD-1 blocking antibody. 21. The method of claim 15, wherein the castalagin or analog thereof is present in a plant or fruit extract. 22. (canceled) 23. The method of claim 15, wherein the method comprises administering a pharmaceutical composition comprising castalagin. 24. The method of claim 15, wherein the castalagin or analog thereof is formulated for delivery of the castalagin or analog thereof into the intestines. 25. (canceled) 26. The method of claim 15, wherein the cancer is lung cancer or breast cancer. 27. The method of claim 26, wherein the lung cancer is non-small cell lung cancer (NSCLC), and wherein the breast cancer is triple-negative breast cancer (TNBC). 28-57. (canceled)"
claim_text_053_807_865_739_075 = "What is claimed is: 1. A method of inducing allograft tolerance in a recipient subject comprising: administering prior to donor organ or tissue transplantation in the subject, a pharmaceutical composition comprising one or more anti-CD3 immunotoxin and a pharmaceutical composition comprising peripheral blood cells obtained from the donor of the donor organ or tissue and inducing allograft tolerance in the recipient subject to the donor organ. 2. The method according to claim 1, wherein administering the pharmaceutical composition comprising peripheral blood cells obtained from the donor comprises infusing the peripheral blood cell composition into the subject. 3. The method according to claim 1, wherein administering the pharmaceutical composition comprising peripheral blood cells obtained from the donor comprises administering the peripheral blood cell composition before, during, simultaneously, and/or after administering the pharmaceutical composition comprising the anti-CD3 immunotoxin to the subject. 4. The method according to claim 1, further comprising transplanting a solid organ, tissue or cells from the donor into the recipient. 5. The method according to claim 4, wherein the donor solid organ, donor tissue, or donor cells comprise kidney, heart, lung, liver, intestine, pancreas, skin, vascular composite allografts (VCAs), leukocytes, hepatocytes, pancreatic islets, corneal epithelial cells, bone marrow (hematopoietic stem cells, HCT) or a combination thereof. 6. The method according to claim 4, further comprising assessing allo-antibody or anti-donor antibody production in the subject before, during and/or after transplantation of the donor solid organ or tissue into the recipient. 7. The method according to claim 1, further comprising administering an immunosuppressant to the subject. 8. The method according to claim 4, wherein the transplanting of the donor solid organ or donor tissue comprises transplanting the donor solid organ or donor tissue at a time when both T cells and B cells are repressed. 9. (canceled) 10. The method according to claim 1, wherein administering the peripheral donor blood cells to the subject occurs with minimal to no peripheral donor blood cell engraftment. 11. The method according to claim 1, wherein the anti-CD3 immunotoxin comprises a recombinant fusion toxin. 12. The method according to claim 11, wherein the recombinant fusion toxin comprises an anti-human CD3 binding domain and a truncated diphtheria toxin. 13. The method according to claim 12, wherein the anti-human CD3 binding domain comprises an anti-human CD3 epsilon specific monoclonal antibody and the truncated diphtheria toxin comprises a translocation and a catalytic domain of a truncated diphtheria toxin. 14. The method according to claim 7, wherein the immunosuppressant comprises one or more of a steroid, Janus kinase inhibitors, calcineurin inhibitors, mTOR inhibitors, IMDH inhibitors, polyclonal antibodies, and monoclonal antibodies. 15. The method according to claim 14, wherein the immunosuppressant comprises one or more immunosuppressant comprising prednisone (e.g. Deltasone, Orasone), budesonide (Entocort EC), prednisolone (Millipred), tofacitinib (Xeljanz), cyclosporine (Neoral, Sandimmune, SangCya), tacrolimus (Astagraf XL, Envarsus XR, Prograf), sirolimus (Rapamune), everolimus (Afinitor, Zortress), azathioprine (Azasan, Imuran), leflunomide (Arava), mycophenolate (CellCept, Myfortic), abatacept (Orencia), adalimumab (Humira), anakinra (Kineret), certolizumab (Cimzia), etanercept (Enbrel), golimumab (Simponi), infliximab (Remicade), ixekizumab (Taltz), natalizumab (Tysabri), rituximab (Rituxan), secukinumab (Cosentyx), tocilizumab (Actemra), ustekinumab (Stelara), vedolizumab (Entyvio), basiliximab (Simulect), daclizumab or (Zinbryta). 16. The method according to claim 14, wherein the immunosuppressant comprises one or more of tacrolimus, mycophenolate and a steroid. 17. The method according to claim 1, wherein MHC compatibility of donor and recipient is selected from fully MHC-matched, haplo-mismatched, or fully mismatched. 18. The method according to claim 1, 2 of 3, wherein the peripheral donor blood cells are obtained without at least one of cytokine mobilization and stem cell enrichment. 19. (canceled) 20. A pharmaceutical composition comprising, one or more anti-CD3 immunotoxin; and peripheral blood cells obtained from a donor of an organ. 21. (canceled) 22. A kit comprising the pharmaceutical composition according to claim 20; and at least one container. 23. A method for depleting T cells in organs and tissues of a subject comprising administering one or more anti-CD3 immunotoxin to a subject in need of such a treatment. 24. (canceled) 25. The method according to claim 23, wherein the subject has GvHD. 26-28. (canceled)"
claim_text_029_853_159_129_12X = "1. A non-peripheral quaternary ammonium-modified zinc phthalocyanine, having a structural formula shown as follows: Figure US20230075925A1-20230309-C00007 2. A preparation method of the non-peripheral quaternary ammonium-modified zinc phthalocyanine according to claim 1, comprising the following steps: conducting a reaction on 1-[4-(aminoethyl)phenoxy] zinc phthalocyanine and methyl iodide as reactants in N,N-dimethylformamide as a solvent under the protection of nitrogen at 0° C. to a room temperature for 5 h to 50 h; and removing impurities by solvent cleaning and column chromatography isolation to obtain 1-[4-(N,N,N-trimethyl-2-aminoethyl)phenoxy] zinc phthalocyanine iodide. 3. The preparation method according to claim 2, wherein the 1-[4-(aminoethyl)phenoxy] zinc phthalocyanine and the methyl iodide have a mass ratio of 1:(50-200). 4. The preparation method according to claim 2, wherein 1 mg of the 1-[4-(aminoethyl)phenoxy] zinc phthalocyanine requires 0.3 mL to 3 mL of the N,N-dimethylformamide. 5. A preparation method of a photodynamic drug or a photosensitizer comprising using the non-peripheral quaternary ammonium-modified zinc phthalocyanine according to claim 1. 6. The preparation method according to claim 5, wherein the non-peripheral quaternary ammonium-modified zinc phthalocyanine is capable of inhibiting a distal tumor in combination with an immune checkpoint blocker PD-L1 antibody. 7. The preparation method according to claim 5, wherein the photosensitizer or the photodynamic drug prepared by the non-peripheral quaternary ammonium-modified zinc phthalocyanine is capable of treating a tumor in combination with an immune checkpoint blocker. 8. The preparation method according to claim 5, wherein the photodynamic drug or the photosensitizer is used for a photodynamic therapy (PDT), photodynamic diagnosis, or photodynamic disinfection. 9. The preparation method according to claim 8, wherein the PDT comprises a PDT of a malignant tumor, a PDT of a benign tumor, an in vitro photodynamic purification therapy of leukemia, or a PDT of a non-cancer disease. 10. The preparation method according to claim 9, wherein the non-cancer disease comprises a bacterial infection, an oral disease, a macular degeneration-caused eye disease, arteriosclerosis, a traumatic infection, a skin disease, or a viral infection. 11. The preparation method according to claim 8, wherein the photodynamic disinfection comprises photodynamic sterilization and purification of blood or a blood derivative, photodynamic sterilization and disinfection of water, and photodynamic disinfection of a medical or household appliance. 12-20. (canceled) 21. The preparation method according to claim 7, wherein the photodynamic drug or the photosensitizer is used for a photodynamic therapy (PDT), photodynamic diagnosis, or photodynamic disinfection. 22. The preparation method according to claim 21, wherein the PDT comprises a PDT of a malignant tumor, a PDT of a benign tumor, an in vitro photodynamic purification therapy of leukemia, or a PDT of a non-cancer disease. 23. The preparation method according to claim 22, wherein the non-cancer disease comprises a bacterial infection, an oral disease, a macular degeneration-caused eye disease, arteriosclerosis, a traumatic infection, a skin disease, or a viral infection. 24. The preparation method according to claim 21, wherein the photodynamic disinfection comprises photodynamic sterilization and purification of blood or a blood derivative, photodynamic sterilization and disinfection of water, and photodynamic disinfection of a medical or household appliance."
claim_text_022_873_617_525_132 = "1. A composition comprising a compound that inhibits a binding interaction between an epidermal growth factor receptor (EGFR) and a heat shock protein 90 (HSP90). 2. The composition of claim 1, wherein the compound is a peptide or peptide analog. 3. (canceled) 4. The composition of claim 2, wherein the compound comprises 4 to 10 consecutive amino acids of amino acids 688 to 955 of SEQ ID NO: 1. 5. The composition of claim 4, wherein the compound comprises 4 to 10 consecutive amino acids from amino acids 761-781 of the EGFR. 6. The composition of claim 5, wherein the compound comprises the amino acid sequence DNPH (SEQ ID NO: 13) or RLLGIC (SEQ ID NO: 14). 7. The composition of claim 6, wherein the compound comprises the amino acid sequence SVDNPH (SEQ ID NO: 15), or SVDNPHV (SEQ ID NO: 16), or SVDNPHVX (SEQ ID NO: 17), wherein X is C, S, G, V, or A. 8. The composition of claim 2, wherein the compound comprises an amino acid sequence of SVDNPH (SEQ ID NO: 15) with up to two amino acid substitutions. 9. The composition of claim 8, wherein the amino acid substitution(s) occur(s) at one or two of the positions 1, 3, and 5 of SVDNPH (SEQ ID NO: 15). 10.-12. (canceled) 13. The composition of any of claim 8, wherein the peptide or peptidomimetic comprises an amino acid sequence selected from the group consisting of: AVDNPH, (SEQ ID NO: 25) DVDNPH, (SEQ ID NO: 26) IVDNPH, (SEQ ID NO: 27) SVGNPH, (SEQ ID NO: 28) SVDNGH, (SEQ ID NO: 29) and SVAAPH. (SEQ ID NO: 30) 14. The composition of any of claim 2, comprising an intramolecular bridge which covalently links the side chains of two amino acids of the compound. 15.-21. (canceled) 22. The composition of claim 14, comprising the amino acid sequence XDNPHX (SEQ ID NO: 32), wherein the side chains of the amino acids at positions 1 and 6 are covalently linked by the intramolecular bridge. 23.-25. (canceled) 26. The composition of any of claim 22, comprising the amino acid sequence SXDNPHXX (SEQ ID NO: 33), wherein the X at position 8 is C, S, G, V, or A. 27.-29. (canceled) 30. The composition of any of claim 2, wherein the peptide or peptide analog is fused to a cell penetrating peptide (CPP). 31. (canceled) 32. The composition of any of claim 2, comprising a peptide delivery agent. 33.-39. (canceled) 40. The composition of claim 1, comprising a pharmaceutically acceptable carrier, diluents, or excipient. 41. (canceled) 42. A method of treating cancer in a subject comprising administering to the subject a composition of claim 40 in an amount effective to treat the cancer. 43. The method of claim 42, wherein the cancer is characterized by overexpression of EGFR or expression of a mutant EGFR. 44.-49. (canceled) 50. A method of sensitizing tumors to radiation therapy, chemotherapy, or a combination thereof, in a subject, comprising administering to the subject a composition of any of claim 1 in an amount effective to sensitize the tumors to the therapy. 51.-53. (canceled) 54. A kit comprising the composition of claim 1 in combination with an agent used in radiation therapy or chemotherapy. 55.-64. (canceled)"
claim_text_058_165_013_366_539 = "1. A method of treating a cancer or viral infection in an individual, comprising administering into the individual an effective amount of an antagonist targeting PLA2G2D signaling pathway. 2. The method of claim 1, wherein the antagonist is an antagonist inhibits or downregulates PLA2G2D. 3. The method of claim 2, wherein the PLA2G2D is a human PLA2G2D. 4. The method of claim 2 or claim 3, wherein the antagonist decreases enzymatic activity level of PLA2G2D. 5. The method of claim 4, wherein the antagonist targeting PLA2G2D signaling pathway blocks a catalytic site on PLA2G2D. 6. The method of claim 5, wherein the antagonist targets the H67 catalytic site on a human PLA2G2D according to SEQ ID NO: 1 or 5. 7. The method of any one of claims 1-3, wherein the antagonist comprises a siRNA, an miRNA, an antisense RNA, or a gene editing system. 8. The method of any one of claims 1-3, wherein the antagonist blocks the binding of PLA2G2D to an immune cell. 9. The method of claim 8, wherein the immune cell is a T cell. 10. The method of any one of claims 1-3, wherein the antagonist comprises an anti-PLA2G2D antibody. 11. The method of claim 10, wherein the anti-PLA2G2D antibody is a monoclonal antibody. 12. The method of claim 10, wherein the antagonist is a fusion protein or immunoconjugate further comprising a second moiety. 13. The method of claim 12, wherein the second moiety comprises a cytokine. 14. The method of any one of claims 1-3, wherein the antagonist comprises an inhibitory PLA2G2D polypeptide that blocks the binding of PLA2G2D to an immune cell. 15. The method of claim 14, wherein the inhibitory PLA2G2D polypeptide binds to the immune cell with a greater affinity than a wildtype PLA2G2D. 16. The method of claim 15, wherein the immune cells is a T cell. 17. The method of any one of claims 14-16, wherein inhibitory PLA2G2D polypeptide further comprises a stabilizing domain. 18. The method of claim 17, wherein the stabilizing domain is an Fc domain. 19. The method of any one of claims 14-18, wherein the inhibitory PLA2G2D polypeptide has a length of about 50 to about 200 amino acids. 20. The method of any one of claims 14-19, wherein the inhibitory PLA2G2D polypeptide has a) a mutation at a position corresponding to histidine at position 67 (H67) according to SEQ ID NO: 1 or 5 or b) a mutation at the position corresponding to glycine at position 80 (G80) according to SEQ ID NO: 5. 21. The method of claim 20, wherein the inhibitory PLA2G2D polypeptide comprises an amino acid sequence selected from the group consisting of SEQ ID NOs: 3, 4, and 7-12 or a variant thereof. 22. The method of any one of claims 1-21, wherein the disease or condition is a cancer. 23. The method of claim 22, wherein the cancer is a solid tumor. 24. The method of claim 22 or claim 23, wherein the cancer is an advanced or malignant tumor. 25. The method of any one of claims 22-24, wherein the cancer has an increased expression level of PLA2G2D. 26. The method of any one of claims 22-25, wherein the cancer is selected from the group consisting of lung cancer, breast cancer, liver cancer, gastric cancer, cervical cancer, endometrial cancer, thyroid cancer, colorectal cancer, head and neck cancer, pancreatic cancer, renal cancer, prostate cancer, urothelial cancer, testis cancer, ovarian cancer and melanoma. 27. The method of any one of claims 1-21, wherein the disease or condition is a viral infection. 28. The method of claim 27, wherein the expression level of PLA2G2D at an infected site is higher than that of an uninfected site. 29. The method of any one of claims 1-28, wherein the method further comprises administering a second agent. 30. The method of claim 29, wherein the second agent is selected from the group consisting of a chemotherapeutic agent, an immunomodulator, an anti-angiogenesis agent, a growth inhibitory agent, and an antineoplastic agent. 31. The method of claim 30, wherein the second agent is an immunomodulator. 32. The method of claim 31, wherein the immunomodulator is an immune checkpoint inhibitor. 33. The method of claim 28, wherein the immune checkpoint inhibitor specifically target PD-L1, PD-L2, CTLA4, PD-L2, PD-1, CD47, TIGIT, GITR, TIM3, LAG3, CD27, 4-1BB, or B7H4. 34. The method of claim 33, wherein the second agent comprises a cell comprising a chimeric antigen receptor that specifically binds to a tumor antigen. 35. The method of any one of claims 29-34, wherein the antagonist and the second agent are administered simultaneously or concurrently. 36. The method of any one of claims 29-34, wherein the antagonist and the second agent are administered sequentially. 37. The method of any one of claims 1-36, wherein the antagonist and/or the second agent is administered parentally. 38. The method of any one of claims 22-37, wherein the antagonist is administered to the cancer tissue or infection site directly. 39. The method of any one of claims 1-38, wherein the antagonist is administered at a dose of about 0.001 μg/kg to about 100 mg/kg. 40. The method of any one of claims 22-39, wherein the individual has an increased number of immune cells in the cancer tissue or at the infection site after administration of the antagonist. 41. The method of claim 40, wherein the immune cells are T cells. 42. The method of claim 40 or claim 41, wherein the T cells are activated T cells. 43. The method of any one of claim 40-42, wherein the number of immune cells in the cancer tissue or at the infection site is increased by at least about 5% after administration of the antagonist. 44. The method of any one of claims 22-43, wherein immune cells in the cancer tissue or at the infection site produce an increased level of a cytokine after administration of the antagonist. 45. The method of claim 44, wherein the cytokine is IFNγ and/or IL-2. 46. The method of claim 39 or claim 40, wherein the level of the cytokine is increased by at least about 5% after administration of the antagonist."
claim_text_184_270_747_563_446 = "The invention claimed is: 1. An antibody or an antigen-binding fragment, analog or derivative thereof, directed against a heparanase enzyme, wherein the antibody, antigen-binding fragment, analog or derivative thereof comprises six complementarity-determining regions (CDRs), of SEQ ID NO: 1 to SEQ ID NO: 6. 2. The antibody or antigen-binding fragment, analog or derivative of claim 1, wherein said antibody or antigen-binding fragment, analog or derivative is murine or human or is humanized. 3. The antibody or antigen-binding fragment, analog or derivative of claim 1, comprising the amino acid sequence of SEQ ID NO: 7 or SEQ ID NO: 8. 4. The antibody or antigen-binding fragment, analog or derivative of claim 1, wherein the antibody fragment is selected from the group consisting of: Fab, Fab′, F(ab′)2, Fd, Fd′, Fv, dAb, isolated CDR region, single chain antibody, diabodies, and linear antibodies. 5. A pharmaceutical composition comprising the antibody or antigen-binding fragment, analog or derivative of claim 1 and a pharmaceutical acceptable carrier. 6. An isolated polynucleotide sequence encoding the antibody of claim 1. 7. The isolated polynucleotide sequence of claim 6, comprising the nucleotide sequence as set forth in SEQ ID NO: 9 to SEQ ID NO: 16. 8. A vector comprising the polynucleotide sequence of claim 6. 9. A cell comprising the antibody or antigen-binding fragment, analog or derivative of claim 1. 10. A cell comprising the isolated polynucleotide sequence of claim 6. 11. A cell comprising the vector of claim 8. 12. A pharmaceutical composition comprising the isolated polynucleotide sequence of claim 6 and a pharmaceutically acceptable carrier. 13. A pharmaceutical composition comprising the vector of claim 8 and a pharmaceutically acceptable carrier."
claim_text_196_857_624_941_935 = "1. An anti-LAG3 monoclonal antibody, wherein the anti-LAG3 monoclonal antibody comprises a heavy chain variable region comprising HCDR1, HCDR2 and HCDR3 identical to CDR sequences of the heavy chain variable region as shown in SEQ ID NO: 2, 6 or 10, and a light chain variable region comprising LCDR1, LCDR2 and LCDR3 identical to CDR sequences of the light chain variable region as shown in SEQ ID NO: 4, 8 or 12. 2. The anti-LAG3 monoclonal antibody of claim 1, wherein the anti-LAG3 monoclonal antibody comprises: 1) heavy chain complementarity determining regions: HCDR1 having an amino acid sequence as shown in SEQ ID No: 18, HCDR2 having an amino acid sequence as shown in SEQ ID No: 19, and HCDR3 having an amino acid sequence as shown in SEQ ID No: 20 or 21; and 2) light chain complementarity determining regions: LCDR1 having an amino acid sequence as shown in SEQ ID No: 22 or 23, LCDR2 having an amino acid sequence as shown in SEQ ID No: 24, and LCDR3 having an amino acid sequence as shown in SEQ ID No: 25. 3. The anti-LAG3 monoclonal antibody of claim 2, wherein the anti-LAG3 monoclonal antibody comprises a heavy chain variable region having an amino acid sequence as shown in SEQ ID NO: 2, 6 or 10, or a sequence with at least 85% homology thereto; and a light chain variable region having an amino acid sequence as shown in SEQ ID NO: 4, 8 or 12, or a sequence with at least 85% homology thereto. 4. The anti-LAG3 monoclonal antibody of claim 2, wherein the anti-LAG3 monoclonal antibody comprises a heavy chain composed of a heavy chain variable region having an amino acid sequence as shown in SEQ ID NO: 2, 6 or 10, or a sequence with at least 85% homology thereto, and a heavy chain constant region as shown in SEQ ID NO: 14; and a light chain composed of a light chain variable region having an amino acid sequence as shown in SEQ ID NO: 4, 8 or 12, or a sequence with at least 85% homology thereto, and a light chain constant region as shown in SEQ ID NO: 16. 5. The anti-LAG3 monoclonal antibody of claim 1, wherein the anti-LAG3 monoclonal antibody is a full-length sequence of the antibody or an antigen-binding fragment comprising the anti-LAG3 antibody, wherein the antigen-binding fragment of the anti-LAG3 antibody is Fab, Fab′, F(ab′)2, Fv or scFv. 6. A nucleotide molecule, wherein the nucleotide molecule encodes the anti-LAG3 monoclonal antibody of claim 1. 7. The nucleotide molecule of claim 6, wherein in the nucleotide molecule, the nucleotide sequence encoding the heavy chain variable region of the anti-LAG3 monoclonal antibody is as shown in SEQ ID NO: 3, 7 or 11, and the nucleotide sequence encoding the light chain variable region of the anti-LAG3 monoclonal antibody is as shown in SEQ ID NO: 5, 9 or 13. 8. An expression vector, wherein the expression vector contains the nucleotide molecule of claim 6. 9. The expression vector of claim 8, wherein the expression vector is selected from one or more of pHLX101, pEE14.4, pCHO 1.0 or pcDNA3.1. 10. A host cell, wherein the host cell contains the expression vector of claim 8. 11. The host cell of claim 10, wherein the host cell is selected from one or more of COS, CHO, an HeLa cell line, a myeloid cell line such as an SP2/0 cell line, NS0, sf9, sf21, DH5α, BL21(DE3) or E. coli TG1, a YB2/0 cell line and a transformed B cell or a hybridoma cell. 12. A method for preparing the anti-LAG3 monoclonal antibody of claim 1, comprising the following steps: a) culturing a host cell containing an expression vector containing a nucleotide molecule encoding the anti-LAG3 monoclonal antibody of claim 1 to express the anti-LAG3 monoclonal antibody under an expression condition; and b) isolating and purifying the anti-LAG3 monoclonal antibody obtained in step a). 13. A composition, wherein the composition comprises the anti-LAG3 monoclonal antibody of claim 1 and a pharmaceutically acceptable carrier. 14. A method for resisting tumors, treating autoimmune diseases, and treating infectious diseases and/or resisting transplantation rejection reactions, comprising administering the anti-LAG3 monoclonal antibody of claim 1 or a composition comprising the anti-LAG3 monoclonal antibody of claim 1. 15. The method of claim 14, wherein the anti-LAG3 monoclonal antibody is administered alone or in combination with a drug for resisting tumors selected from an antibody drug and a small-molecule drug for resisting tumors. 16. A method of resisting tumors, treating autoimmune diseases, and treating infectious diseases and/or resisting transplantation rejection reactions, comprising administering the composition of claim 13. 17. The method of claim 14, the composition further comprises a drug for resisting tumors selected from an antibody drug and a small-molecule drug for resisting tumors. 18. The method of claim 15, wherein the antibody drug is an anti-PD-1 monoclonal antibody. 19. The method of claim 15, wherein the small-molecule drug is paclitaxel or 5-fluorouracil."
claim_text_013_287_333_155_311 = "A pharmaceutical composition comprising: i) a herpes gE protein, an active fragment of the protein, a variant of the protein, or a mixture of at least two of them, ii) an immunostimulatory composition comprising a saponin and a CpG oligodeoxynucleotide, or consisting of an adjuvant comprising a saponin and a CpG oligodeoxynucleotide, wherein the sequence of the CpG oligodeoxynucleotide has two or more copies of 5′-TTCGTT-3′ motif or 5′-TCGTCGTCG-3′ motif. 2. The pharmaceutical composition according to claim 1, wherein the sequence of the CpG oligodeoxynucleotide is selected from: CpG T1: TCG TTC OTT CGT TCG TTC OTT (SEQ ID NO: 2); CpG T2: TCG TTC OTT CGT TCG TTC GTT CGT T (SEQ ID NO: 3); and CpG T3: TCG TCG TCG TCG TCG TCG TCG (SEQ ID NO: 4); preferably, the sequence of the CpG oligodeoxynucleotide is CpG T1: TCG TTC OTT CGT TCG TTC GTT (SEQ ID NO: 2). 3. The pharmaceutical composition according to claim 1 or 2, wherein the saponin is one or more selected from the group consisting of quillaja saponin, ginsenoside, platycodin, astragaloside, notoginsenoside, glycyrrhizin, cortex albiziae saponin, ophiopogonin, saikosaponin and panax japonicus saponin. 4. The pharmaceutical composition according to claim 3, wherein the quillaja saponin is QS-7, QS-17, QS-18 or QS-21, preferably QS-21; the ginsenoside is ginsenoside Rg1, ginsenoside Rg3, ginsenoside Rb1 or ginsenoside Re; the platycodin is platycodin D, platycodin D2 or a mixture thereof; the astragaloside is astragalin A, astragaloside I, astragaloside H, or a mixture of two or more of these saponin monomers; the notoginseng saponin is notoginsenoside R1; the ophiopogonin is ophiopogonin D; the saikosaponin is saikosaponin a, saikosaponin d or a mixture thereof; the cortex albiziae saponin is cortex albiziae total saponins; the glycyrrhizin is total glycyrrhizins; and the panax japonicus saponin is panax japonicus total saponins. 5. The pharmaceutical composition according to any one of claims 1 to 4, wherein the adjuvant comprising a saponin is Iscom adjuvant. 6. The pharmaceutical composition according to any one of claims 1 to 5, wherein the CpG oligodeoxynucleotide comprises a phosphorothioate linkage. 7. The pharmaceutical composition according to any one of claims 1 to 6, wherein the CpG oligodeoxynucleotide is a thio-oligodeoxynucleotide. 8. The pharmaceutical composition according to any one of claims 1 to 7, wherein the CpG oligodeoxynucleotide is a perthio-oligodeoxynucleotide. 9. The pharmaceutical composition according to any one of claims 1 to 8, wherein the weight ratio of the CpG oligodeoxynucleotide to the saponin is 1˜40:0.1˜2, preferably 2˜40:0.1˜2. 10. The pharmaceutical composition according to any one of claims 1 to 9, wherein the weight ratio of the CpG oligodeoxynucleotide to the saponin is 2:1. 11. The pharmaceutical composition according to any one of claims 1 to 10, wherein the pharmaceutical composition further comprises: iii) a pharmaceutically acceptable carrier. 12. The pharmaceutical composition according to any one of claims 1 to 11, wherein the herpes gE protein comprises or consists of the amino acid sequence shown by SEQ ID NO: 1. 13. The pharmaceutical composition according to any one of claims 1 to 12, wherein the active fragment of the herpes gE protein comprises or consists of consecutive amino acids from position 1 to position X of SEQ ID NO: 1, wherein X is an integer between 507 and 518. 14. The pharmaceutical composition according to any one of claims 1 to 13, wherein the weight ratio between Components i) and ii) is 1:1.1˜42, preferably 1:2.1˜42. 15. The pharmaceutical composition according to any one of claims 1 to 14, wherein the weight ratio between Components i) and ii) is 1:3. 16. A herpes zoster or varicella vaccine comprising the pharmaceutical composition of any one of claims 1 to 15. 17. Use of the pharmaceutical composition according to any one of claims 1 to 15 in the preparation of a medicament for preventing and/or treating a varicella-zoster virus infection and/or a varicella-zoster virus mediated disease. 18. The use according to claim 17, wherein the varicella-zoster virus infection and/or the varicella-zoster virus mediated disease is selected from the group consisting of varicella, herpes zoster, and postherpetic neuralgia. 19. Use of the pharmaceutical composition according to any one of claims 1 to 15 in the preparation of a medicament for generating a humoral immune response and/or a cellular immune response against varicella-zoster virus in a subject. 20. The use according to claim 19, wherein the medicament is a herpes zoster vaccine or a varicella vaccine. 21. A method for preventing and/or treating a varicella-zoster virus infection and/or a varicella-zoster virus mediated disease comprising administering to a subject in need thereof an effective amount of the pharmaceutical composition according to any one of claims 1 to 15. 22. The method according to claim 21, wherein the varicella-zoster virus infection and/or the varicella-zoster virus mediated disease is selected from the group consisting of varicella, herpes zoster, and postherpetic neuralgia. 23. A method for generating a humoral immune response and/or a cellular immune response against varicella-zoster virus in a subject comprising administering to a subject in need thereof an effective amount of the pharmaceutical composition according to any one of claims 1 to 15."
claim_text_098_651_403_196_496 = "1. A method of producing an antibody-drug conjugate represented by Formula (I), Figure US20230074385A1-20230309-C00018 in the formula, Ab is an antibody or an antigen-binding fragment thereof, D is eribulin, m is an integer of 1 to 10, and p is an integer of 1 to 8, the method comprising: a step 1 of obtaining a compound represented by Formula (B) by reaction of eribulin or a salt thereof with a compound represented by Formula (A), Figure US20230074385A1-20230309-C00019 in the formula, m is an integer of 1 to 10 and X is a phenoxy group or a nitrophenoxy group, and Figure US20230074385A1-20230309-C00020 in the formula, m is an integer of 1 to 10; and a step 2 of obtaining the antibody-drug conjugate represented by Formula (I) by reaction of the compound represented by Formula (B) with Ab. 2. The method according to claim 1, wherein Ab comprises (i) a heavy chain domain comprising an amino acid sequence represented by SEQ ID NO: 1 and a light chain domain comprising an amino acid sequence represented by SEQ ID NO: 6, (ii) a heavy chain variable domain comprising an amino acid sequence represented by SEQ ID NO: 23 and a light chain variable domain comprising an amino acid sequence represented by SEQ ID NO: 24, (iii) a heavy chain variable domain comprising an amino acid sequence represented by SEQ ID NO: 27 and a light chain variable domain comprising an amino acid sequence represented by SEQ ID NO: 28, or (iv) a heavy chain domain comprising an amino acid sequence represented by SEQ ID NO: 347 and a light chain domain comprising an amino acid sequence represented by SEQ ID NO: 308. 3. The method according to claim 1 or 2, wherein p is 3 or 4. 4. The method according to any one of claims 1 to 3, wherein eribulin or the salt thereof is eribulin methanesulfonate. 5. The method according to any one of claims 1 to 4, wherein the step 1 is performed in the presence of a base. 6. A method of producing a compound represented by Formula (B), Figure US20230074385A1-20230309-C00021 in the formula, m is an integer of 1 to 10, the method comprising: a step of obtaining a compound represented by Formula (B) by reaction of eribulin or a salt thereof with a compound represented by Formula (A), Figure US20230074385A1-20230309-C00022 in the formula, m is an integer of 1 to 10 and X is a phenoxy group or a nitrophenoxy group. 7. The method according to claim 6, wherein the step is performed in the presence of a base. 8. A compound represented by Formula (A), Figure US20230074385A1-20230309-C00023 in the formula, m is an integer of 1 to 10 and X is a phenoxy group or a nitrophenoxy group."

# %%
#Filled in the df with missing claims
df.loc[df["lens_id"] == "032-240-698-890-336", "claims_text"] = claim_text_032_240_698_890_336
df.loc[df["lens_id"] == "053-807-865-739-075", "claims_text"] = claim_text_053_807_865_739_075
df.loc[df["lens_id"] == "029-853-159-129-12X", "claims_text"] = claim_text_029_853_159_129_12X
df.loc[df["lens_id"] == "022-873-617-525-132", "claims_text"] = claim_text_022_873_617_525_132
df.loc[df["lens_id"] == "058-165-013-366-539", "claims_text"] = claim_text_058_165_013_366_539
df.loc[df["lens_id"] == "184-270-747-563-446", "claims_text"] = claim_text_184_270_747_563_446
df.loc[df["lens_id"] == "196-857-624-941-935", "claims_text"] = claim_text_196_857_624_941_935
df.loc[df["lens_id"] == "013-287-333-155-311", "claims_text"] = claim_text_013_287_333_155_311
df.loc[df["lens_id"] == "098-651-403-196-496", "claims_text"] = claim_text_098_651_403_196_496

# %%
(df["claims_text"] == "").sum() #outputs 0, meaning there are no longer missing claims text in the df
# Out:
# np.int64(0)

# %% [markdown]
# ---
#
# ## Prepare files for API input
# The next step is to prepare the text files to be inputted into API
# - The three texts I can provide are Title, Abstract and Claims
#
# <br>
#
# <span style="background-color: yellow; color: black;">Note the limitations</span>
# - If the claims references SEQ ID NO or Structures or Figures, I did not provide and include this information
# - SEQ ID tables would significantly increase token length and are beyond the scope of this case study
# - It would also require conversion of images into text, which would add preprocessing complexity

# %%
def extract_title(biblio):
    if not isinstance(biblio, dict):
        return ""
    
    titles = biblio.get("invention_title", [])
    
    if isinstance(titles, list) and len(titles) > 0:
        return titles[0].get("text", "")
    
    return ""

df["title"] = df["biblio"].apply(extract_title)

# %%
def extract_abstract(abstract_obj):
    if not isinstance(abstract_obj, list) or len(abstract_obj) == 0:
        return ""
    
    first_entry = abstract_obj[0]
    
    if isinstance(first_entry, dict):
        return first_entry.get("text", "")
    
    return ""

df["abstract_text"] = df["abstract"].apply(extract_abstract)

# %%
export_df = df[[
    "lens_id",
    "title",
    "abstract_text",
    "claims_text"
]].copy()

export_df = export_df.fillna("")

# %%
export_df.to_csv("../../data/processed/patents_for_ai.csv", index=False)

# %% [markdown]
# ---
#
# ## API Validation Using a Manually Curated Patent Set

# %% [markdown]
# First, the API will be tested on a manually curated patent list, specifically the ABL patents I have examined in "5c_neok001_portfolio.ipynb"
#
# This is done to test the prompts and edit the prompt (to fine tune and fix any errors)
#
# _NOTE: this is a subset of the total ABL Bio's portfolio, it is 24 out of the final 37_
# - For more info on which patents were used, look at "abl_patents_for_ai.csv"

# %% [markdown]
# ##### **AI-based Section was ran in a data science course folder**
# AI-based classification components were executed within a course-provided data science git hub repo
# - Because they provided an OpenAI API gateway key, pre-configured environment dependencies, and required Python packages
#
# While execution occurred within the course environment, full scripts used for API-based claim classification are included below, along with the output screenshots
#
# **<span style="background-color: yellow; color: black;">The code cells below were ran in that course git hub repo folder.</span>**
#
# **<span style="background-color: yellow; color: black;">Code cells starting at "Examine Patent Composition in ADC Oncology Space in US Jurisdiction" returns back to running on this repo</span>**

# %%
import pandas as pd
document_folder = "../../05_src/assignment_chat/"

abl_df = pd.read_csv("abl_patents_for_ai.csv")

# %%
#Provide the developer prompt
instructions =''' You are a pharmaceutical patent analyst specializing in antibody-drug conjugates (ADCs).
Classify patents based on claims content, not just title/abstract language. 
If a patent includes both composition claims and method-of-treatment claims, classify based on the broadest independent claim.
Follow strict JSON format. Keep reasoning_short concise (2-4 sentences).'''

# %%
#User prompt
prompt='''Analyze the following patent:
TITLE:
{title}
ABSTRACT:
{abstract}
CLAIMS:
{claims}

Instructions:
Step 1. Determine the primary patent_type:
- "Composition" → Claims a drug, biologic, ADC construct, antibody, linker, payload, or therapeutic composition.
- "CMC" → Focuses on manufacturing, conjugation process, DAR control, purification, formulation, stability, analytical methods, or scale-up.
- "Clinical" → Focuses on treatment methods, dosing regimens, patient populations, combination therapies, or clinical use.
- "Other" → Does not primarily fall into the above categories.

Choose only ONE primary category based on the main inventive concept.

Step 2. If patent_type = "Composition", classify composition_subtype as ONE of:
- "Full ADC" → Specifies antibody + linker + payload.
- "Conjugated Linker" → Linker specified; antibody/payload broadly defined.
- "Conjugated Payload" → Payload specified; antibody/linker broadly defined.
- "Conjugated Antibody" → Antibody specified; linker/payload broadly defined.
- "Dual Combination" → Two of the three components (e.g., linker + payload) specified.
- "Unconjugated Linker" → Linker intermediate only.
- "Unconjugated Antibody" → Antibody intermediate only.
- "Unconjugated Payload" → Payload intermediate only.
- null → if not applicable.

Step 3. If patent_type = "CMC", classify cmc_subtype as ONE of:
- "DAR Control" → Controlling drug-to-antibody ratio or heterogeneity.
- "Conjugation Method" → Site-specific conjugation, enzymatic methods, engineered cysteines, glycan methods, click chemistry.
- "Process/Scale-Up" → Manufacturing optimization, yield improvement, reaction conditions.
- "Purification/Downstream" → Chromatography, aggregate removal, impurity removal.
- "Formulation/Stability" → Buffer systems, storage stability, lyophilization.
- "Analytical/Characterization" → DAR measurement, LC-MS methods, assay development.
- "Intermediate Production" → Linker/payload activated intermediates.
- null → if not applicable.

Step 4. If patent_type = "Clinical":
- Extract disease indications that are explicitly claimed as being treated, prevented, or managed.
- Do NOT extract diseases mentioned only in background or examples.
- Extract specific patient populations only if they are part of a claimed method (e.g., refractory patients, HER2+, metastatic, pediatric, etc.).

Return ONLY valid JSON in this format:
{{
  "patent_type": "",
  "composition_subtype": null,
  "cmc_subtype": null,
  "clinical_indications": [],
  "clinical_population": [],
  "reasoning_short": ""
}}

'''

# %%
def classify_patent(row):
    filled_prompt = prompt.format(
        title=row['title'],
        abstract=row['abstract_text'],
        claims=row['claims_text']
    )
    
    response = client.chat.completions.create(
        model="gpt-4o-mini", #specify model
        messages=[
            {"role": "system", "content": instructions},
            {"role": "user", "content": filled_prompt}
        ],
        response_format={"type": "json_object"},
        temperature=0
    )
    
    return json.loads(response.choices[0].message.content)

# %%
results = []
for idx, row in abl_df.iterrows():
    print(f"Processing {idx+1}/{len(abl_df)}: {row['lens_id']}")
    try:
        result = classify_patent(row)
        result['lens_id'] = row['lens_id']
        results.append(result)
    except Exception as e:
        print(f"  Error: {e}")
        results.append({'lens_id': row['lens_id'], 'error': str(e)})

results_df = pd.DataFrame(results)
results_df.to_csv("abl_patents_classified.csv", index=False)
print("Done!")
results_df.head()

# %% [markdown]
# I ran this with model gpt-4o and with gpt-4o-mini to compare the labeling results
# - As expected, there is a decrease in quality for mini
# - The broader bins (composition or clinical or CMC) remains the same; so macro-level classification is still strong in 4o-mini
# - But subtype labeling is weaker
# - 4o-mini model classifies plain antibodies and bispecific antibodies as "conjugated antibody" even when no linker or payload is present
# - The reasoning is even "classifying it as a conjugated antibody since it specifies the antibody structure without detailing a linker or payload.” → which is contradictory (conceptual drift)
# - Though mini was able to extract more disease detail
#
# <br>
#
# **Overall, suggests:**
# - Macro-level patent type classification remained stable,
# - Clinical entity extraction improved
# - Structural classification degraded (subtype prediction)

# %% [markdown]
# **results_df.head() for 4o-model results:**
# ![title](../../data/images/abl_bio_api_test_4o.png)
# - The file can also be found in this repo, as `data/ai_results/abl_patents_classified_4o_model.csv`
#
# <br>
#
# **results_df.heaf for 4o-mini results**:
# ![title](../../data/images/abl_bio_api_test_4omini.png)
# - The file can also be found in this repo, as `data/ai_results/abl_patents_classified_4omini_model.csv`

# %% [markdown]
# ### **Comparison of Manual to API Classification**

# %% [markdown]
# **Manual Categorization**
# I already manually assessed a subset of ABL Bio patents, which I put in as `data/processed/abl_patents_for_ai.csv` and based on my examination, they were classified as _(Family number based on csv order)_:
#
# 1) Pure Antibody Composition Patents (n = 9)
#     - Families: 2, 4, 5, 7, 9, 12, 13, 15, 19
#     - These are classic composition-of-matter antibody filings focused on specific antigen-binding sequences.
#
# 2) Bi-Specific Antibody Composition Patents (n = 10)
#     - Families: 1, 8, 11, 14, 17, 18, 20, 21, 22, 24
#     - These patents claim dual-targeting antibody constructs
#
# 3) ADC Composition Patents (Antibody–Drug Conjugates) (n = 3)
#     - Families: 3, 16, 23
#     - These fell into three distinct structural subtypes:
#         - Family 3 – Linker Platform Patent
#         - Family 16 – Payload-Centric Patent
#         - Family 23 – Full ADC Platform
#
# 4) Clinical Filing (n = 1)
#     - Family: 10 | With the title, “A method of treating a solid tumor”
#
# 5) CMC / Manufacturing Patent (n = 1)
#     - Family: 6 | With the title: “Method for Purifying Biologically Active Peptide by Using Protein A Affinity Chromatography”
#
# <br>
#
# **API Categorization**
# The APIs successfully categorized patents into the high-level buckets I gave: Composition, Clinical, CMC

# %% [markdown]
# ### Trying to reduct ambiguity in subtype definition
#
# However, mini is overinterpreting “multi-component antibody” as conjugated.
# - Need to edit prompt to define conjugation as covalent attachment to non-antibody payload
# - Explicitly define bispecific antibodies as unconjugated
# - Anchor everything to the broadest independent claim
# - Add a decision hierarchy (ADC first, then antibody, then clinical, etc.)

# %%
instructions = """
You are a pharmaceutical patent analyst specializing in antibody and antibody-drug conjugate (ADC) intellectual property.
Core principles:
- Base classification strictly on the BROADEST INDEPENDENT CLAIM.
- Prioritize structural claim scope over background, examples, or dependent claims.
- Distinguish clearly between:
  • Unconjugated antibodies (including bispecific/multispecific constructs)
  • Chemically conjugated antibodies (require covalent attachment to a non-antibody payload)
- Multiple binding domains do NOT constitute conjugation.
- Only classify as "Clinical" if the broadest independent claim is a method-of-treatment claim.
- Only classify as "CMC" if the primary inventive concept is manufacturing or process-focused.
Be conservative and structurally precise.
Return strict JSON only.
Keep reasoning_short concise (2–4 sentences).
"""

# %%
prompt = '''Analyze the following patent:
TITLE:
{title}
ABSTRACT:
{abstract}
CLAIMS:
{claims}

Instructions:
IMPORTANT:
- Base all classification on the BROADEST INDEPENDENT CLAIM.
- Prioritize structural claim scope over background description.
- If multiple claim types exist, choose the dominant inventive concept.
------------------------------------------------------
Step 1. Determine the primary patent_type:
- "Composition" → Claims a chemical or biologic entity (antibody, ADC, linker, payload, or defined therapeutic construct).
- "CMC" → Focuses primarily on manufacturing processes, purification, conjugation methods, DAR control, formulation, analytical methods, or scale-up.
- "Clinical" → Claims a method of treatment, dosing regimen, patient population, or clinical use as the primary inventive concept.
- "Other" → Does not primarily fall into the above categories.
Choose ONLY ONE primary category.
If a patent contains both composition and method-of-treatment claims:
→ Select "Composition" IF the broadest independent claim is directed to the molecule/construct itself.
------------------------------------------------------
Step 2. If patent_type = "Composition", classify composition_subtype as ONE of:
DEFINITIONS:
- "Full ADC" → Explicitly claims antibody + linker + cytotoxic payload in a single defined construct.
- "Conjugated Linker" → Claims a specific linker for antibody conjugation; antibody/payload broadly defined.
- "Conjugated Payload" → Claims a specific cytotoxic payload for antibody conjugation; antibody/linker broadly defined.
- "Conjugated Antibody" → Antibody is covalently conjugated to a non-antibody payload (drug, toxin, radioisotope, etc.). Requires chemical conjugation.
- "Dual Combination" → Two of the three ADC components (e.g., linker + payload) are structurally defined together.
- "Unconjugated Antibody" → Antibody or bispecific/multispecific antibody ONLY. No covalent attachment to drug/toxin.
- "Unconjugated Linker" → Linker intermediate only.
- "Unconjugated Payload" → Cytotoxic drug intermediate only.
- null → if not applicable.
CRITICAL RULE:
- Bispecific or multispecific antibodies WITHOUT a covalently attached payload are classified as "Unconjugated Antibody".
- Multiple binding domains ≠ conjugation.
- Conjugation requires chemical attachment to a non-antibody payload.
------------------------------------------------------
Step 3. If patent_type = "CMC", classify cmc_subtype as ONE of:
- "DAR Control"
- "Conjugation Method"
- "Process/Scale-Up"
- "Purification/Downstream"
- "Formulation/Stability"
- "Analytical/Characterization"
- "Intermediate Production"
- null
------------------------------------------------------
Step 4. If patent_type = "Clinical":
- Extract ONLY diseases explicitly claimed in a treatment method.
- Do NOT extract diseases mentioned only in background.
- Extract patient populations ONLY if part of a claimed method (e.g., metastatic, HER2+, refractory).
------------------------------------------------------
Return ONLY valid JSON in this format:
{{
  "patent_type": "",
  "composition_subtype": null,
  "cmc_subtype": null,
  "clinical_indications": [],
  "clinical_population": [],
  "reasoning_short": ""
}}
'''

# %%
def classify_patent(row):
    filled_prompt = prompt.format(
        title=row['title'],
        abstract=row['abstract_text'],
        claims=row['claims_text']
    )
    
    response = client.chat.completions.create(
        model="gpt-4o-mini", #specify model
        messages=[
            {"role": "system", "content": instructions},
            {"role": "user", "content": filled_prompt}
        ],
        response_format={"type": "json_object"},
        temperature=0
    )
    
    return json.loads(response.choices[0].message.content)

# %%
results = []
for idx, row in abl_df.iterrows():
    print(f"Processing {idx+1}/{len(abl_df)}: {row['lens_id']}")
    try:
        result = classify_patent(row)
        result['lens_id'] = row['lens_id']
        results.append(result)
    except Exception as e:
        print(f"  Error: {e}")
        results.append({'lens_id': row['lens_id'], 'error': str(e)})

results_df = pd.DataFrame(results)
results_df.to_csv("abl_patents_classified.csv", index=False)
print("Done!")
results_df.head()

# %% [markdown]
# **The new results with v2 prompt:**
# ![title](../../data/images/abl_bio_api_test_4ominiv2.png)
# - The file can also be found in this repo, as `data/ai_results/abl_patents_classified_4o_mini_model_v2.csv`
#
#
# Subtyping is better but you'll notice clinical is now being overcalled
# - Lens ID 084-986-690-232-010 → classified as Clinical
# - Lens ID 141-040-150-695-864 → classified as Clinical
# - Lens ID 013-169-852-887-496 → classified as Clinical
#
# Seems to be over-prioritizing method-of-treatment claims even when composition is likely the broadest claim

# %%
#Try again with emphasis in developer prompt
instructions = """
You are a pharmaceutical patent analyst specializing in antibody and ADC intellectual property.

STRICT DECISION PROCESS:

1. Identify Claim 1 (or the first independent claim).
2. If Claim 1 claims a molecule, antibody, ADC, linker, payload, or defined construct → classify as "Composition".
3. Only classify as "Clinical" if Claim 1 itself is a method-of-treatment claim.
4. Only classify as "CMC" if Claim 1 is primarily directed to a manufacturing or process method.
5. Do NOT override Composition simply because treatment claims appear later.

Structural rules:
- Bispecific/multispecific antibodies WITHOUT covalent drug attachment = "Unconjugated Antibody".
- Conjugation requires covalent attachment to a non-antibody payload.
- Be conservative and structurally precise.

Return strict JSON only.
Keep reasoning_short concise (2–4 sentences).
"""

# %% [markdown]
# **The results of v3 mini:**
# ![title](../../data/images/abl_bio_api_test_4ominiv3.png)
# - The file can also be found in this repo, as `data/ai_results/abl_patents_classified_4o_mini_model_v3.csv`

# %% [markdown]
# Less conjugated antibodies being identified
# - Before mini overcalled conjugation because it saw ADC language anywhere
# - Now, mini undercalls conjugation unless Claim 1 is ADC
#
# The addition of 'If Claim 1 is composition → classify as Composition' has stabilized Clinical vs Composition
# - But it also means if conjugation language appears only in later independent claims, mini might miss it
# - Model will label conjugated/ADC if: Claim 1 explicitly says so or covalent attachment is clearly in the broadest independent claim
# - So it’s structurally conservative

# %% [markdown]
# For my objective (portfolio categorization), this is sufficient
#
# However, for more detailed analysis (Like Freedom-to-operate, invalidity analysis, platform IP depth evaluation), this would not be

# %% [markdown]
# ## Run API with v3 prompt in 4o-mini with entire 2,331 patent collection

# %%
fullpatents = pd.read_csv("patents_for_ai.csv")
fullpatents.shape #confirmed it is 2331

# %%
import time

results = []
for idx, row in fullpatents.iterrows():
    print(f"Processing {idx+1}/{len(fullpatents)}: {row['lens_id']}")
    try:
        result = classify_patent(row)
        result['lens_id'] = row['lens_id']
        results.append(result)
    except Exception as e:
        print(f"  Error on {row['lens_id']}: {e}")
        results.append({'lens_id': row['lens_id'], 'error': str(e)})
    
    time.sleep(0.5)  # small delay between calls

results_df = pd.DataFrame(results)
results_df.to_csv("patents_classified_v3mini.csv", index=False)
print("Done!")

# %% [markdown]
# The file can also be found in this repo, as `data/ai_results/patents_classified_v3mini.csv`

# %% [markdown]
# ---
# **<span style="background-color: yellow; color: black;">Code cells below are back to running on this repo</span>**
#
# ## Examine Patent Composition in ADC Oncology Space in US Jurisdiction

# %% [markdown]
# ### Load in files

# %%
import pandas as pd
df = pd.read_json("../../data/raw/US-enforced-patents.jsonl", lines=True)

classified_df = pd.read_csv("../../data/ai_results/patents_classified_v3mini.csv")

# %%
#Attach results to df of ~2000 patent families 
pd.set_option('display.max_colwidth', 100)
final_df = df.merge(classified_df, on='lens_id', how='left')
final_df.head()
# Out:
#                lens_id jurisdiction   doc_number kind date_published  \
# 0  001-164-692-658-169           US      9107960   B2     2015-08-18
# 1  039-300-232-515-637           US      9334318   B1     2016-05-10
# 2  094-825-731-979-424           US     12318455   B2     2025-06-03
# 3  165-451-121-516-190           US  20160129013   A1     2016-05-12
# 4  064-424-066-709-583           US     11944689   B2     2024-04-02
#
#                       doc_key   docdb_id lang  \
# 0      US_9107960_B2_20150818  443471947   en
# 1      US_9334318_B1_20160510  452042120   en
# 2     US_12318455_B2_20250603  631938788   en
# 3  US_20160129013_A1_20160512  452234872   en
# 4     US_11944689_B2_20240402  609044858   en
#
#                                                                                                 biblio  \
# 0  {'publication_reference': {'jurisdiction': 'US', 'doc_number': '9107960', 'kind': 'B2', 'date': ...
# ...

# %% [markdown]
# ---
#
# ## Examine Patent Composition in the US ADC Oncology Space

# %%
type_summary = (
    final_df['patent_type']
    .value_counts()
    .reset_index()
)
type_summary.columns = ['patent_type', 'count']
type_summary['percent'] = (
    type_summary['count'] / type_summary['count'].sum() * 100
)
type_summary
# Out:
#    patent_type  count    percent
# 0     Clinical   1235  52.981553
# 1  Composition   1064  45.645646
# 2          CMC     28   1.201201
# 3        Other      4   0.171600

# %%
final_df["publication_type"].value_counts()
# Out:
# publication_type
# PATENT_APPLICATION    1761
# GRANTED_PATENT         570
# Name: count, dtype: int64

# %% [markdown]
# ~75% of ADC simple families in this dataset do not yet have a granted member

# %%
status_by_type = (
    final_df
    .groupby(["patent_type", "publication_type"])
    .size()
    .unstack(fill_value=0)
)

status_pct = status_by_type.div(
    status_by_type.sum(axis=1), axis=0
) * 100

status_pct.round(1)
# Out:
# publication_type  GRANTED_PATENT  PATENT_APPLICATION
# patent_type
# CMC                         32.1                67.9
# Clinical                    24.5                75.5
# Composition                 24.3                75.7
# Other                        0.0               100.0

# %%
#Examining subtype may be less accurate (saw undercalling of conjugation) but for insight and estimation:
comp_df = final_df[final_df['patent_type'] == 'Composition']

print(comp_df['composition_subtype'].value_counts())
print("\n", comp_df['composition_subtype'].value_counts(normalize=True) * 100)
# Out:
# composition_subtype
# Unconjugated Antibody    374
# Full ADC                 230
# Conjugated Antibody      134
# Dual Combination          32
# Conjugated Payload        28
# Conjugated Linker         21
# Other                      1
# Name: count, dtype: int64
#
#  composition_subtype
# Unconjugated Antibody    45.609756
# Full ADC                 28.048780
# Conjugated Antibody      16.341463
# Dual Combination          3.902439
# Conjugated Payload        3.414634
# Conjugated Linker         2.560976
# Other                     0.121951
# Name: proportion, dtype: float64

# %%
final_df["date_published"] = pd.to_datetime(
    final_df["date_published"],
    errors="coerce"
)

# %%
final_df["year"] = final_df["date_published"].dt.year

# %%
counts = pd.crosstab(
    final_df["year"],
    final_df["publication_type"]
)

percentages = counts.div(counts.sum(axis=1), axis=0) * 100
percentages = percentages.round(1)

# %%
combined = counts.astype(str) + " (" + percentages.astype(str) + "%)"
combined
# Out:
# publication_type GRANTED_PATENT PATENT_APPLICATION
# year
# 2006                   0 (0.0%)         1 (100.0%)
# 2008                   0 (0.0%)         2 (100.0%)
# 2009                  1 (33.3%)          2 (66.7%)
# 2010                   0 (0.0%)         6 (100.0%)
# 2011                  3 (30.0%)          7 (70.0%)
# 2012                  7 (35.0%)         13 (65.0%)
# 2013                  4 (33.3%)          8 (66.7%)
# 2014                 12 (37.5%)         20 (62.5%)
# 2015                 21 (41.2%)         30 (58.8%)
# 2016                 19 (34.5%)         36 (65.5%)
# 2017                 20 (32.3%)         42 (67.7%)
# 2018                 34 (42.5%)         46 (57.5%)
# 2019                 42 (33.1%)         85 (66.9%)
# 2020                 59 (43.1%)         78 (56.9%)
# 2021                 45 (23.4%)        147 (76.6%)
# 2022                 82 (27.3%)        218 (72.7%)
# 2023                 72 (18.5%)        318 (81.5%)
# ...

# %% [markdown]
# ---
#
# ## Examine the Top Assignees

# %%
final_df.columns #look for column where company names would be
# Out:
# Index(['lens_id', 'jurisdiction', 'doc_number', 'kind', 'date_published',
#        'doc_key', 'docdb_id', 'lang', 'biblio', 'families', 'sequence_listing',
#        'legal_status', 'abstract', 'claims', 'description', 'publication_type',
#        'patent_type', 'composition_subtype', 'cmc_subtype',
#        'clinical_indications', 'clinical_population', 'reasoning_short',
#        'year'],
#       dtype='str')

# %%
final_df.loc[0, 'biblio'] #The biblio column contains a dictionary including the applicant and owner names
# Out:
# {'publication_reference': {'jurisdiction': 'US',
#   'doc_number': '9107960',
#   'kind': 'B2',
#   'date': '2015-08-18'},
#  'application_reference': {'jurisdiction': 'US',
#   'doc_number': '201414255508',
#   'kind': 'A',
#   'date': '2014-04-17'},
#  'application_number': '14/255,508',
#  'priority_claims': {'claims': [{'jurisdiction': 'US',
#     'doc_number': '201414255508',
#     'kind': 'A',
#     'date': '2014-04-17',
#     'sequence': 1},
#    {'jurisdiction': 'US',
#     'doc_number': '201313948732',
#     'kind': 'A',
#     'date': '2013-07-23',
#     'sequence': 2},
#    {'jurisdiction': 'US',
#     'doc_number': '201261736684',
#     'kind': 'P',
#     'date': '2012-12-13',
#     'sequence': 3},
#    {'jurisdiction': 'US',
#     'doc_number': '201361749548',
#     'kind': 'P',
#     'date': '2013-01-07',
#     'sequence': 4}],
#   'earliest_claim': {'date': '2012-12-13'}},
#  'invention_title': [{'text': 'Antibody-SN-38 immunoconjugates with a CL2A linker',
# ...

# %% [markdown]
# > #### Data Format Note
# >
# > **5a (Global landscape):** CSV export from Lens.org
# > The assignee is pre-parsed as flat text, multiple assignees delimited by `;;`.
# > Owner used where available, applicant as fallback:
# > ```python
# > df['Assignee'] = df['Owners'].fillna(df['Applicants'])
# > ```
# > .
# >
# > **5b-1 & -2 (US landscape):** jsonl export required to access claims text.
# > Assignee extracted from nested `biblio` JSON structure:
# > ```python
# > owners = record.get("parties", {}).get("owners_all", [])
# > # fallback to applicants if no owner recorded
# > ```
# >
# > Both approaches used will apply the same priority logic: owner > applicant.
# > The format difference reflects Lens.org export limitations; since claims text is only available in jsonl, not with CSV bulk export.

# %%
#jsonl format, must extract from nested biblio JSON
#There are some rows where owner column is filled and is different from applicant
import ast

# 1. extract applicants
def extract_applicants(record):
    try:
        if isinstance(record, str):
            record = ast.literal_eval(record)
        applicants = record.get("parties", {}).get("applicants", [])
        names = [a.get("extracted_name", {}).get("value") for a in applicants]
        return [n for n in names if n]
    except:
        return []
    
final_df["applicant_list"] = final_df["biblio"].apply(extract_applicants)

# %%
# 2. extract owners
def extract_owners(record):
    try:
        if isinstance(record, str):
            record = ast.literal_eval(record)
        owners = record.get("parties", {}).get("owners_all", [])
        names = [o.get("extracted_name", {}).get("value") for o in owners]
        return [n for n in names if n]
    except:
        return []

final_df["owner_list"] = final_df["biblio"].apply(extract_owners)
print(f"No owners: {final_df['owner_list'].apply(lambda x: len(x) == 0).sum()} / {len(final_df)}")

# 3. create assignee (where will use owner if available, otherwise applicant)
final_df["assignee_list"] = final_df.apply(
    lambda row: row["owner_list"] if len(row["owner_list"]) > 0 else row["applicant_list"],
    axis=1
)
# Out:
# No owners: 455 / 2331

# %%
#Grab owner information from biblio data
def extract_applicants(record):
    try:
        # If stored as string, convert to dict
        if isinstance(record, str):
            record = ast.literal_eval(record)

        applicants = record.get("parties", {}).get("applicants", [])
        names = [a.get("extracted_name", {}).get("value") for a in applicants]
        return names
    except:
        return []

final_df["assignee_list"] = final_df["biblio"].apply(extract_applicants)

# %%
#Explode to one Row per Applicant
exploded_df = final_df.explode("assignee_list")

# %%
top_companies = (
    exploded_df["assignee_list"]
    .value_counts()
)

top_companies.head(30)
# Out:
# assignee_list
# GENENTECH INC                                    79
# DAIICHI SANKYO CO LTD                            51
# HOFFMANN LA ROCHE                                37
# UNIV TEXAS                                       35
# NOVARTIS AG                                      34
# JANSSEN BIOTECH INC                              31
# BRISTOL MYERS SQUIBB CO                          30
# UNIV CALIFORNIA                                  29
# IMMUNOGEN INC                                    27
# MEDIMMUNE LTD                                    26
# SEAGEN INC                                       24
# DANA FARBER CANCER INST INC                      21
# EISAI R&D MAN CO LTD                             20
# MAYO FOUND MEDICAL EDUCATION & RES               20
# UNIV PENNSYLVANIA                                19
# L E A F HOLDINGS GROUP LLC                       18
# MERCK SHARP & DOHME LLC                          17
# MEMORIAL SLOAN KETTERING CANCER CENTER           17
# ...

# %%
#What % of ADC families are controlled by top 10 filers?
top_companies.head(10).sum() / len(final_df["lens_id"].unique())
# Out:
# np.float64(0.1625911625911626)

# %% [markdown]
# So top 10 filers control about 16% of US ADC patent families

# %% [markdown]
# ### Look at Patent Composition of Top 50 (volume-based) companies in US ADC Oncology Space
#
# Patent type breakdown (Composition / Clinical / CMC / Other) computed across the top 50 assignees by patent family count in the US-enforced patent dataset

# %%
top50_names = top_companies.head(50).index.tolist()

top50_df = exploded_df[
    exploded_df["assignee_list"].isin(top50_names)
]

# %%
portfolio_breakdown = (
    top50_df
    .groupby(["assignee_list", "patent_type"])
    .size()
    .unstack(fill_value=0)
)

portfolio_breakdown = portfolio_breakdown.reindex(top50_names)
portfolio_breakdown
# Out:
# patent_type                                     CMC  Clinical  Composition  \
# assignee_list
# GENENTECH INC                                     0        58           21
# DAIICHI SANKYO CO LTD                             4         9           38
# HOFFMANN LA ROCHE                                 0        28            9
# UNIV TEXAS                                        0        27            8
# NOVARTIS AG                                       1        13           19
# JANSSEN BIOTECH INC                               0        27            4
# BRISTOL MYERS SQUIBB CO                           0        21            9
# UNIV CALIFORNIA                                   0        20            9
# IMMUNOGEN INC                                     4         7           16
# MEDIMMUNE LTD                                     0        12           14
# SEAGEN INC                                        0        19            5
# ...

# %%
#For percentage
portfolio_pct = portfolio_breakdown.div(
    portfolio_breakdown.sum(axis=1),
    axis=0
) * 100

portfolio_pct = portfolio_pct.reindex(top50_names)

portfolio_pct.round(1)
# Out:
# patent_type                                      CMC  Clinical  Composition  \
# assignee_list
# GENENTECH INC                                    0.0      73.4         26.6
# DAIICHI SANKYO CO LTD                            7.8      17.6         74.5
# HOFFMANN LA ROCHE                                0.0      75.7         24.3
# UNIV TEXAS                                       0.0      77.1         22.9
# NOVARTIS AG                                      2.9      38.2         55.9
# JANSSEN BIOTECH INC                              0.0      87.1         12.9
# BRISTOL MYERS SQUIBB CO                          0.0      70.0         30.0
# UNIV CALIFORNIA                                  0.0      69.0         31.0
# IMMUNOGEN INC                                   14.8      25.9         59.3
# MEDIMMUNE LTD                                    0.0      46.2         53.8
# SEAGEN INC                                       0.0      79.2         20.8
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# color palette
colors = [
    '#0072B2',  # blue       — Clinical
    '#E69F00',  # orange     — Composition
    '#009E73',  # green      — CMC
    '#CC79A7',  # pink       — Other
]

# %%
# ── DATA ─────────────────────────────────────────────────────
labels   = ['Clinical', 'Composition', 'CMC', 'Other']
counts   = [1235, 1064, 28, 4]
total    = sum(counts)
threshold = 2.0

# ── PLOT ─────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(6, 7))

wedges, _, _ = ax.pie(
    counts,
    labels=None,
    colors=colors,
    autopct='',
    startangle=90,
    wedgeprops=dict(width=0.5,
                    edgecolor='white',
                    linewidth=2),
)

# ── MANUAL LABELS ─────────────────────────────────────────────
for i, (wedge, count) in enumerate(zip(wedges, counts)):
    pct = count / total * 100
    angle = (wedge.theta1 + wedge.theta2) / 2
    x = np.cos(np.radians(angle))
    y = np.sin(np.radians(angle))

    if pct >= threshold:
        ax.text(x * 0.75, y * 0.75,
                f'{pct:.1f}%\n({count:,})',
                ha='center', va='center',
                fontsize=10, fontweight='bold',
                color='white')
    else:
        if i == 2:  # CMC
            xytext = (x * 1.45, y * 1.35)
        else:       # Other — push left
            xytext = (-0.15, 1.55)

        ax.annotate(
            f'{labels[i]}\n{pct:.1f}% ({count})',
            xy=(x * 0.85, y * 0.85),
            xytext=xytext,
            ha='center', va='center',
            fontsize=8.5, color='#475569',
            arrowprops=dict(arrowstyle='-',
                           color='#CBD5E1', lw=1.0)
        )

# ── CENTER TEXT ───────────────────────────────────────────────
ax.text(0,  0.11, 'Total',
        ha='center', fontsize=10, color='#94A3B8')
ax.text(0, -0.04, f'{total:,}',
        ha='center', fontsize=20, fontweight='bold',
        color='#1E293B')
ax.text(0, -0.143, 'US Patents',
        ha='center', fontsize=9, color='#94A3B8')

# ── LEGEND — all 4 in bottom ─────────────────────────────────
legend_handles = [
    mpatches.Patch(color=colors[i],
                   label=f'{labels[i]}  ({counts[i]:,})')
    for i in range(len(labels))
]
ax.legend(handles=legend_handles,
          loc='upper right',
          bbox_to_anchor=(1.3, 1.1),
          ncol=1,
          fontsize=9.5,
          framealpha=0)

plt.tight_layout()
plt.savefig('../../data/images/05b_IP_patent_type_donut.png',
            dpi=150, bbox_inches='tight',
            facecolor='white')
plt.show()
print("Saved to data/images/05b_IP_patent_type_donut.png")
# Out:
# Saved to data/images/05b_IP_patent_type_donut.png

# %%
# ── DATA — top 50, sorted by volume (descending) ─────────────
# portfolio_pct already ordered by top50_names from earlier cell
# reverse so largest volume ends up at TOP of horizontal bar chart
plot_df = portfolio_pct.iloc[::-1].copy()

# clean display names
name_map = {
    'ASTRAZENECA UK LTD': 'AstraZeneca UK',
    'L E A F HOLDINGS GROUP LLC': 'L E A F Holdings',
    'TORAY INDUSTRIES': 'Toray Industries',
    'SHANGHAI HENGRUI PHARMACEUTICAL CO LTD': 'Shanghai Hengrui',
    'JIANGSU HENGRUI MEDICINE CO': 'Jiangsu Hengrui',
    'DAIICHI SANKYO CO LTD': 'Daiichi Sankyo',
    'CHIA TAI TIANQING PHARMACEUTICAL GROUP CO LTD': 'Chia Tai Tianqing',
    'ABBVIE INC': 'AbbVie',
    'SANOFI SA': 'Sanofi',
    'US HEALTH': 'US Dept of Health',
    'UNIV PENNSYLVANIA': 'Univ Pennsylvania',
    'MORPHOSYS AG': 'MorphoSys',
    'SICHUAN KELUN BIOTECH BIOPHARMACEUTICAL CO LTD': 'Sichuan Kelun',
    'IMMUNOGEN INC': 'ImmunoGen',
    'UNIV YALE': 'Yale',
    'REGENERON PHARMA': 'Regeneron',
    'NOVARTIS AG': 'Novartis',
    'MEDIMMUNE LTD': 'MedImmune',
    'MEMORIAL SLOAN KETTERING CANCER CENTER': 'Memorial Sloan Kettering',
    'SEATTLE GENETICS INC': 'Seattle Genetics',
    'MAYO FOUND MEDICAL EDUCATION & RES': 'Mayo Clinic',
    'TAKEDA PHARMACEUTICALS CO': 'Takeda',
    'ADC THERAPEUTICS SA': 'ADC Therapeutics',
    'PFIZER': 'Pfizer',
    'HARVARD COLLEGE': 'Harvard',
    'UNIV DUKE': 'Duke',
    'UNIV LELAND STANFORD JUNIOR': 'Stanford',
    'CHUGAI PHARMACEUTICAL CO LTD': 'Chugai',
    'AMGEN INC': 'Amgen',
    'UNIV CALIFORNIA': 'Univ California',
    'MERCK PATENT GMBH': 'Merck Patent GmbH',
    'EISAI R&D MAN CO LTD': 'Eisai',
    'BRISTOL MYERS SQUIBB CO': 'Bristol Myers Squibb',
    'UNIV JOHNS HOPKINS': 'Johns Hopkins',
    'INST NAT SANTE RECH MED': 'INSERM',
    'GENENTECH INC': 'Genentech',
    'HOFFMANN LA ROCHE': 'Hoffmann La Roche',
    'UNIV TEXAS': 'Univ Texas',
    'SEAGEN INC': 'Seagen',
    'DANA FARBER CANCER INST INC': 'Dana Farber',
    'INCYTE CORP': 'Incyte',
    'MASSACHUSETTS GEN HOSPITAL': 'Massachusetts Gen Hospital',
    'JUNO THERAPEUTICS INC': 'Juno Therapeutics',
    'GENMAB AS': 'Genmab',
    'CELGENE CORP': 'Celgene',
    'JANSSEN BIOTECH INC': 'Janssen Biotech',
    'ASTRAZENECA AB': 'AstraZeneca AB',
    'MERCK SHARP & DOHME': 'Merck Sharp & Dohme',
    'IMMUNOMEDICS INC': 'Immunomedics',
    'MERCK SHARP & DOHME LLC': 'Merck Sharp & Dohme LLC',
}

plot_df.index = [name_map.get(n, n) for n in plot_df.index]

# ── COLORS (Okabe-Ito, colorblind-friendly) ──────────────────
c_composition = '#E69F00'   # orange
c_clinical    = '#0072B2'   # blue
c_cmc         = '#009E73'   # green
c_other       = '#CC79A7'   # pink

# ── PLOT ─────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(10, 14))

y_pos = np.arange(len(plot_df))

# stacked bars
ax.barh(y_pos, plot_df['Composition'],
        color=c_composition, label='Composition', zorder=2)
ax.barh(y_pos, plot_df['Clinical'],
        left=plot_df['Composition'],
        color=c_clinical, label='Clinical', zorder=2)
ax.barh(y_pos, plot_df['CMC'],
        left=plot_df['Composition'] + plot_df['Clinical'],
        color=c_cmc, label='CMC', zorder=2)
ax.barh(y_pos, plot_df['Other'],
        left=plot_df['Composition'] + plot_df['Clinical'] + plot_df['CMC'],
        color=c_other, label='Other', zorder=2)

ax.set_yticks(y_pos)
ax.set_yticklabels(plot_df.index, fontsize=8.5)
ax.set_xlim(0, 100)
ax.set_ylim(-0.75, len(plot_df) + 0.25)
ax.set_xlabel('% of Patent Families', fontsize=10)
ax.set_title(
    'Patent Filing Strategy — Top 50 US ADC Oncology Assignees\n'
    'Sorted by Volume (Descending) | AI-Assisted Claim Classification',
    fontsize=12, fontweight='bold', pad=20)

# legend — spread across bottom
ax.legend(loc='lower center',
          bbox_to_anchor=(0.5, -0.065),
          ncol=4,
          fontsize=9,
          framealpha=0.9)

ax.spines[['top', 'right']].set_visible(False)
ax.grid(False)

plt.tight_layout()
plt.savefig('../../data/images/05b_IP_top50_strategy_by_volume.png',
            dpi=150, bbox_inches='tight',
            facecolor='white')
plt.show()
print("Saved to ../../data/images/05b_IP_top50_strategy_by_volume.png")
# Out:
# Saved to ../../data/images/05b_IP_top50_strategy_by_volume.png

# %%
# ── COMPOSITION-ORDERED SORT ─────────────────────────────────
# start fresh from portfolio_pct and sort by Composition %
# ascending=True # lowest composition at row 0 (bottom of chart); highest composition at top of chart
plot_df = portfolio_pct.sort_values('Composition', ascending=True).copy()

# apply clean display names AFTER sorting
plot_df.index = [name_map.get(n, n) for n in plot_df.index]

# %%
# ── PLOT ─────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(10, 14))

y_pos = np.arange(len(plot_df))

# stacked bars
ax.barh(y_pos, plot_df['Composition'],
        color=c_composition, label='Composition', zorder=2)
ax.barh(y_pos, plot_df['Clinical'],
        left=plot_df['Composition'],
        color=c_clinical, label='Clinical', zorder=2)
ax.barh(y_pos, plot_df['CMC'],
        left=plot_df['Composition'] + plot_df['Clinical'],
        color=c_cmc, label='CMC', zorder=2)
ax.barh(y_pos, plot_df['Other'],
        left=plot_df['Composition'] + plot_df['Clinical'] + plot_df['CMC'],
        color=c_other, label='Other', zorder=2)

# archetype threshold lines at 30% and 60% composition
ax.axvline(30, color='#94A3B8', linewidth=1,
           linestyle='--', zorder=3, alpha=0.7)
ax.axvline(60, color='#94A3B8', linewidth=1,
           linestyle='--', zorder=3, alpha=0.7)

# archetype zone labels at top
ax.text(15, len(plot_df) + 0.05, 'Clinical-\ndominant',
        ha='center', fontsize=10, color='#0072B2', fontweight='bold')
ax.text(45, len(plot_df) + 0.4, 'Balanced',
        ha='center', fontsize=10, color='#009E73', fontweight='bold')
ax.text(78, len(plot_df) + 0.05, 'Composition-\ndominant',
        ha='center', fontsize=10, color='#E69F00', fontweight='bold')

ax.set_yticks(y_pos)
ax.set_yticklabels(plot_df.index, fontsize=8.5)
ax.set_xlim(0, 100)
ax.set_xlabel('% of Patent Families', fontsize=10)

ax.legend(loc='lower center',
          bbox_to_anchor=(0.5, -0.065),
          ncol=4,
          fontsize=9,
          framealpha=0.9)
ax.set_title(
    'Patent Filing Strategy — Top 50 US ADC Oncology Assignees\n'
    'Sorted by Composition % (Descending) | AI-Assisted Claim Classification',
    fontsize=12, fontweight='bold', pad=25)
ax.spines[['top', 'right']].set_visible(False)
ax.grid(False)

ax.set_ylim(-0.5, len(plot_df) + 0.5)
plt.tight_layout()
plt.savefig('../../data/images/05b_IP_top50_strategy_by_composition.png',
            dpi=150, bbox_inches='tight',
            facecolor='white')
plt.show()
print("Saved to ../../data/images/05b_IP_top50_strategy_by_composition.png")
# Out:
# Saved to ../../data/images/05b_IP_top50_strategy_by_composition.png
